# %% [markdown]
# **Load Data**

# %%
import pandas as pd
df = pd.read_csv('/root/wind_Energy/dataset/final_la_haute_R0711.csv')
df['Date'] = pd.to_datetime(df['Date_time'])
df['Year'] = df['Date'].dt.year 
df['Month'] = df['Date'].dt.month 
new_data=df[['Month','Year','Date','P_avg']]
new_data=new_data[new_data.Year == 2017]

cap=max(new_data['P_avg'])

# %% [markdown]
# **Parameter Settings**

# %%
i=[1,2,3] #for fold-1
look_back=6
data_partition=0.5257331291956189

# %%
from myfunctions_france import svr_model,ann_model,rf_model,lstm_model,bigru_model,emd_lstm,eemd_lstm,ceemdan_lstm,proposed_method,ceemdan_ewt_evl,ceemdan_ewt_bilstm,ceemdan_ewt_bigru,ceemdan_ewt_transformer,ceemdan_ewt_cnn,ceemdan_ewt_cnn_lstm_attention,ceemdan_ewt_cnn_gru_attention
# Out:
# 2025-11-28 11:51:43.200962: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64
# 2025-11-28 11:51:43.200989: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
CUDA_VISIBLE_DEVICES=""

# %%
svr_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    5.775183
# RMSE 154.4896093730272
# MAE 118.43052718246021

# %%
ann_model(new_data,i,look_back,data_partition,cap)
# Out:
# 2025-11-28 11:51:45.499945: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2025-11-28 11:51:45.633720: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-11-28 11:51:45.636847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.57GiB deviceMemoryBandwidth: 871.81GiB/s
# 2025-11-28 11:51:45.636980: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64
# 2025-11-28 11:51:45.637108: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64
# 2025-11-28 11:51:45.637195: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64
# 2025-11-28 11:51:45.640169: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2025-11-28 11:51:45.640289: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64
# 2025-11-28 11:51:45.640379: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64
# 2025-11-28 11:51:45.640467: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64
# 2025-11-28 11:51:45.640475: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-28 11:51:45.640839: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-28 11:51:45.670122: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2800195000 Hz
# 2025-11-28 11:51:45.676215: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6a7b780 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-11-28 11:51:45.676272: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-11-28 11:51:45.678513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-11-28 11:51:45.678564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# MAPE 4.739679066324999
# RMSE 138.55442895481488
# MAE 97.19564593763441

# %%
rf_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    5.468542
# RMSE 150.19922409707232
# MAE 112.14229483133263

# %%
lstm_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 4.356747894589545
# RMSE 136.29473654205256
# MAE 89.342953368021

# %%
bigru_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 4.236909455794881
# RMSE 136.1221428402619
# MAE 86.88545059118502

# %%
emd_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9323/3756007065.py in <module>
# ----> 1 emd_lstm(new_data,i,look_back,data_partition,cap)
#
# ~/wind_Energy/myfunctions_france.py in emd_lstm(new_data, i, look_back, data_partition, cap)
#     555
#     556         # Fitting the RNN to the Training set
# --> 557         model.fit(trainX, y, epochs = epoch, batch_size = batch_size,verbose=0)
#     558
#     559         # make predictions
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/wind_Energy/venv37/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
eemd_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    2.691787
# RMSE 82.58042195283852
# MAE 55.199935351918

# %%
ceemdan_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.775366
# RMSE 66.06912896607925
# MAE 36.40707175447639

# %%
proposed_method(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.610719
# RMSE 53.39365962092239
# MAE 33.030687346661594

# %%
ceemdan_ewt_evl(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.60794
# RMSE 53.2466146540484
# MAE 32.9736990797861

# %%
ceemdan_ewt_bigru(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.66374
# RMSE 54.15671105206878
# MAE 34.11798715898211

# %%
ceemdan_ewt_bilstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.600148
# RMSE 53.53910670348089
# MAE 32.813910209111064

# %%
ceemdan_ewt_transformer(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_cnn(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_cnn_lstm_attention(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_cnn_gru_attention(new_data,i,look_back,data_partition,cap)
