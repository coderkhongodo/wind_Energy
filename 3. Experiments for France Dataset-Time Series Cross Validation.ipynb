# %% [markdown]
# **Load Data**

# %%
import pandas as pd
df = pd.read_csv('/root/CEEMDAN-EWT-LSTM/dataset/final_la_haute_R0711.csv')
df['Date'] = pd.to_datetime(df['Date_time'])
df['Year'] = df['Date'].dt.year 
df['Month'] = df['Date'].dt.month 
new_data=df[['Month','Year','Date','P_avg']]
new_data=new_data[new_data.Year == 2017]

cap=max(new_data['P_avg'])

# %% [markdown]
# **Parameter Settings**

# %%
i=[1,2] #for fold-1
look_back=6
data_partition=0.5257331291956189

# %%
from myfunctions_france import svr_model,ann_model,rf_model,lstm_model,emd_lstm,eemd_lstm,ceemdan_lstm,proposed_method,ceemdan_ewt_evl,ceemdan_ewt_bilstm,ceemdan_ewt_transformer,ceemdan_ewt_cnn,ceemdan_ewt_cnn_lstm_attention,ceemdan_ewt_cnn_gru_attention
# Out:
# 2025-11-24 21:52:36.614264: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:52:36.614290: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
CUDA_VISIBLE_DEVICES=""

# %%
svr_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    4.864697
# RMSE 137.59350570150775
# MAE 99.75935953908431

# %%
ann_model(new_data,i,look_back,data_partition,cap)
# Out:
# 2025-11-24 21:52:37.964840: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2025-11-24 21:52:37.990715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:68:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.8GHz coreCount: 82 deviceMemorySize: 23.69GiB deviceMemoryBandwidth: 871.81GiB/s
# 2025-11-24 21:52:37.990819: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:52:37.990884: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:52:37.995523: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2025-11-24 21:52:37.995994: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2025-11-24 21:52:37.996092: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:52:37.996167: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:52:37.996242: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:52:37.996254: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-24 21:52:37.996645: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-24 21:52:38.013279: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2499950000 Hz
# 2025-11-24 21:52:38.015266: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x439ac10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-11-24 21:52:38.015299: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-11-24 21:52:38.017516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-11-24 21:52:38.017539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# MAPE 4.055859265427836
# RMSE 134.50685584547455
# MAE 83.1726907284163

# %%
rf_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    4.736453
# RMSE 140.36085835492244
# MAE 97.12949824261777

# %%
lstm_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 3.9256128561122745
# RMSE 130.29165326148276
# MAE 80.50175379211035

# %%
emd_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.940194
# RMSE 67.43409443043605
# MAE 39.787167783501786

# %%
eemd_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    2.691787
# RMSE 82.58042195283852
# MAE 55.199935351918

# %%
ceemdan_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.775366
# RMSE 66.06912896607925
# MAE 36.40707175447639

# %%
proposed_method(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.519416
# RMSE 54.177435454700515
# MAE 31.15835671409868

# %%
ceemdan_ewt_evl(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.522922
# RMSE 53.84302353299231
# MAE 31.230258175189764

# %%
ceemdan_ewt_bilstm(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_transformer(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_cnn(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_cnn_lstm_attention(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_cnn_gru_attention(new_data,i,look_back,data_partition,cap)
