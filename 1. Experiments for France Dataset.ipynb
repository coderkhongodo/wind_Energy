# %% [markdown]
# **Load Data**

# %%
import pandas as pd
df = pd.read_csv('/root/wind_Energy/dataset/final_la_haute_R0711.csv')
df['Date'] = pd.to_datetime(df['Date_time'])
df['Year'] = df['Date'].dt.year 
df['Month'] = df['Date'].dt.month 
new_data=df[['Month','Year','Date','P_avg']]
new_data=new_data[new_data.Year == 2017]

cap=max(new_data['P_avg'])

# %% [markdown]
# **Parameter Settings**

# %%
i=[1] #enter month value, i.e January = 1
look_back=6
data_partition=0.8

# %%
from myfunctions_france import svr_model,ann_model,rf_model,lstm_model,emd_lstm,eemd_lstm,ceemdan_lstm,proposed_method,ceemdan_ewt_evl,ceemdan_ewt_bilstm,ceemdan_ewt_transformer,ceemdan_ewt_cnn,ceemdan_ewt_cnn_lstm_attention,ceemdan_ewt_cnn_gru_attention
# Out:
# 2025-11-27 15:08:56.306703: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 15:08:56.306759: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
CUDA_VISIBLE_DEVICES=""

# %%
svr_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    5.459116
# RMSE 165.74305818893225
# MAE 111.94899554706014

# %%
ann_model(new_data,i,look_back,data_partition,cap)
# Out:
# 2025-11-27 14:30:15.672063: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2025-11-27 14:30:15.827088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:c2:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.58GiB deviceMemoryBandwidth: 871.81GiB/s
# 2025-11-27 14:30:15.827241: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 14:30:15.827285: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 14:30:15.827323: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 14:30:15.827794: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2025-11-27 14:30:15.827838: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 14:30:15.827874: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 14:30:15.827909: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 14:30:15.827915: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-27 14:30:15.828438: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-27 14:30:15.878087: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2249960000 Hz
# 2025-11-27 14:30:15.893680: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x65a4660 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-11-27 14:30:15.893785: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-11-27 14:30:15.894907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-11-27 14:30:15.894923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# MAPE 3.7209253483721145
# RMSE 112.38713995961884
# MAE 76.30426821307192

# %%
rf_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    4.406569
# RMSE 122.08933116295262
# MAE 90.36463111930883

# %%
lstm_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 3.4453957981087338
# RMSE 107.3821678656045
# MAE 70.65403910726039

# %%
emd_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.656104
# RMSE 53.00367786878239
# MAE 33.96139012352698

# %%
eemd_lstm(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.57855
# RMSE 58.54389153434967
# MAE 32.37101555457997

# %%
proposed_method(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.207595
# RMSE 35.976911999753064
# MAE 24.76390588041136

# %%
ceemdan_ewt_evl(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.172338
# RMSE 35.71366934026383
# MAE 24.040897446870463

# %%
ceemdan_ewt_bilstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.207912
# RMSE 36.0898040651774
# MAE 24.77040074574819

# %%
ceemdan_ewt_transformer(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    4.341215
# RMSE 125.241159784736
# MAE 89.02443281836656

# %%
ceemdan_ewt_cnn(new_data,i,look_back,data_partition,cap)
# Out:
# 2025-11-27 15:09:46.005403: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2025-11-27 15:09:46.158797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:c2:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.58GiB deviceMemoryBandwidth: 871.81GiB/s
# 2025-11-27 15:09:46.158911: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 15:09:46.158960: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 15:09:46.159001: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 15:09:46.159459: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2025-11-27 15:09:46.159511: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 15:09:46.159554: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 15:09:46.159596: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-27 15:09:46.159602: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-27 15:09:46.173133: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-27 15:09:46.210079: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2249960000 Hz
# 2025-11-27 15:09:46.224820: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x793d4f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-11-27 15:09:46.224856: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-11-27 15:09:46.226863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-11-27 15:09:46.226883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# MAPE: 13.182425822616617
# RMSE: 300.2564884742948
# MAE: 270.3293566768087
# (13.182425822616617, 300.2564884742948, 270.3293566768087)

# %%
ceemdan_ewt_cnn_lstm_attention(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE: 15.592213051527647
# RMSE: 346.381079955637
# MAE: 319.74637901285416
# (15.592213051527647, 346.381079955637, 319.74637901285416)

# %%
ceemdan_ewt_cnn_gru_attention(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE: 15.37302057451287
# RMSE: 342.8768700815496
# MAE: 315.25144294439997
# (15.37302057451287, 342.8768700815496, 315.25144294439997)
