# %% [markdown]
# **Load Data**

# %%
import pandas as pd
df = pd.read_csv('/root/CEEMDAN-EWT-LSTM/dataset/T1.csv')
new_data = df.dropna(axis = 0, how ='any')

# Xử lý dữ liệu Turkey: Tạo cột 'month' từ Date/Time
# Format: "01 01 2018 00:00" -> parse thành datetime
new_data['Date'] = pd.to_datetime(new_data['Date/Time'], format='%d %m %Y %H:%M', errors='coerce')
new_data['Year'] = new_data['Date'].dt.year
new_data['month'] = new_data['Date'].dt.month  # Tạo cột 'month' (chữ thường) để tương thích với myfunctions.py
new_data = new_data[['month', 'Year', 'Date', 'LV ActivePower (kW)']]  # Chọn các cột cần thiết

new_data.describe()
cap=max(new_data['LV ActivePower (kW)'])

# %% [markdown]
# **Parameter Settings**

# %%
i=[1] #enter month value, i.e January = 1
look_back=6
data_partition=0.8

# %%
from myfunctions import svr_model,ann_model,rf_model,lstm_model,emd_lstm,eemd_lstm,ceemdan_lstm,proposed_method,ceemdan_ewt_evl,ceemdan_ewt_bilstm,ceemdan_ewt_transformer
# Out:
# 2025-11-24 21:04:44.698506: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:04:44.698534: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
CUDA_VISIBLE_DEVICES=""

# %%
svr_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    5.049142
# RMSE 533.7688814824568
# MAE 182.71496603016766

# %%
ann_model(new_data,i,look_back,data_partition,cap)
# Out:
# 2025-11-24 21:04:45.836018: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2025-11-24 21:04:45.865975: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:68:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.8GHz coreCount: 82 deviceMemorySize: 23.69GiB deviceMemoryBandwidth: 871.81GiB/s
# 2025-11-24 21:04:45.866112: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:04:45.866195: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:04:45.870900: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2025-11-24 21:04:45.871368: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2025-11-24 21:04:45.871472: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:04:45.871552: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:04:45.871630: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-11-24 21:04:45.871642: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-24 21:04:45.872085: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-24 21:04:45.884122: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2499950000 Hz
# 2025-11-24 21:04:45.886358: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3548950 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-11-24 21:04:45.886410: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-11-24 21:04:45.889810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-11-24 21:04:45.889846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# MAPE 3.1822402990350342
# RMSE 281.356914985637
# MAE 115.15677698143546

# %%
rf_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    4.340352
# RMSE 395.08887671739456
# MAE 157.06573166294308

# %%
lstm_model(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 2.6134799704045713
# RMSE 269.3753782381881
# MAE 94.57485978937203

# %%
emd_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    5.631491
# RMSE 370.4755077635861
# MAE 203.78862981925394

# %%
eemd_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    2.832718
# RMSE 196.21080904472097
# MAE 102.50850238557535

# %%
ceemdan_lstm(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.642432
# RMSE 167.5912106600298
# MAE 59.43521719233993

# %%
proposed_method(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.383262
# RMSE 121.33458977466671
# MAE 50.05656523449412

# %%
ceemdan_ewt_evl(new_data,i,look_back,data_partition,cap)
# Out:
# MAPE 0    1.380525
# RMSE 120.46653661349586
# MAE 49.95750207173452

# %%
ceemdan_ewt_bilstm(new_data,i,look_back,data_partition,cap)

# %%
ceemdan_ewt_transformer(new_data,i,look_back,data_partition,cap)
